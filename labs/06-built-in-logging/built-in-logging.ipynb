# %% [markdown]
# # APIM ❤️ OpenAI
#
# ## Built-in logging lab
# ![flow](../../images/built-in-logging.gif)
#
# Playground to try the [buil-in logging capabilities of API Management](https://learn.microsoft.com/en-us/azure/api-management/observability). The requests are logged into Application Insights and it's easy to track request/response details and token usage with provided [notebook](openai-usage-analysis-workbook.json).
#
# ### Backlog
# - Improve the notebook
# - Use the [trace policy](https://learn.microsoft.com/en-us/azure/api-management/trace-policy) to send aditional info within the policy
# - Add OpenAI diagnostics
#
# ### Prerequisites
# - [Python 3.8 or later version](https://www.python.org/) installed
# - [Pandas Library](https://pandas.pydata.org/) installed
# - [VS Code](https://code.visualstudio.com/) installed with the [Jupyter notebook extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) enabled
# - [Azure CLI](https://learn.microsoft.com/en-us/cli/azure/install-azure-cli) installed
# - [An Azure Subscription](https://azure.microsoft.com/en-us/free/) with Contributor permissions
# - [Access granted to Azure OpenAI](https://aka.ms/oai/access) or just enable the mock service
# - [Sign in to Azure with Azure CLI](https://learn.microsoft.com/en-us/cli/azure/authenticate-azure-cli-interactively)

# %% [markdown]
# ### 0️⃣ Initialize notebook variables
#
# - Resources will be suffixed by a unique string based on your subscription id
# - The ```mock_webapps``` variable sets the list of deployed Web Apps for the mocking functionality. Clean the ```openai_resources``` list to simulate the OpenAI behaviour with the mocking service.
# - Adjust the location parameters according your preferences and on the [product availability by Azure region.](https://azure.microsoft.com/en-us/explore/global-infrastructure/products-by-region/?cdn=disable&products=cognitive-services,api-management)
# - Adjust the OpenAI model and version according the [availability by region.](https://learn.microsoft.com/en-us/azure/ai-services/openai/concepts/models)

# %%
import os
import json
import datetime
import requests

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
#resource_group_name = f"lab-{deployment_name}" # change the name to match your naming style
resource_group_name = "lab-ai-gateway-03456"
resource_group_location = "westeurope"
apim_resource_name = "apim0L6"
apim_resource_location = "westeurope"
apim_resource_sku = "Basicv2"
openai_resources = [ {"name": "openai1", "location": "swedencentral"}, {"name": "openai2", "location": "francecentral"} ] # list of OpenAI resources to deploy. Clear this list to use only the mock resources
openai_resources_sku = "S0"
openai_model_name = "gpt-35-turbo"
openai_model_version = "0613"
openai_deployment_name = "gpt-35-turbo"
openai_api_version = "2024-02-01"
openai_specification_url='https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/' + openai_api_version + '/inference.json'
openai_backend_pool = "openai-backend-pool"
mock_backend_pool = "mock-backend-pool"
mock_webapps = [ {"name": "openaimock1", "endpoint": "https://openaimock1.azurewebsites.net"}, {"name": "openaimock2", "endpoint": "https://openaimock2.azurewebsites.net"} ]

log_analytics_name = "workspace"
app_insights_name = 'insights'

# %% [markdown]
# ### 1️⃣ Create the Azure Resource Group
# All resources deployed in this lab will be created in the specified resource group. Skip this step if you want to use an existing resource group.

# %%
resource_group_stdout = ! az group create --name {resource_group_name} --location {resource_group_location} --tags owner=massimo.crippa@codit.eu
if resource_group_stdout.n.startswith("ERROR"):
    print(resource_group_stdout)
else:
    print("✅ Azure Resource Grpup ", resource_group_name, " created ⌚ ", datetime.datetime.now().time())
# Out:
# ✅ Azure Resource Grpup  lab-ai-gateway-03456  created ⌚  09:23:02.414726

# %% [markdown]
# ### 2️⃣ Create deployment using 🦾 Bicep
#
# This lab uses [Bicep](https://learn.microsoft.com/en-us/azure/azure-resource-manager/bicep/overview?tabs=bicep) to declarative define all the resources that will be deployed. Change the parameters or the [main.bicep](main.bicep) directly to try different configurations.

# %%
if len(openai_resources) > 0:
    backend_id = openai_backend_pool if len(openai_resources) > 1 else openai_resources[0].get("name")
elif len(mock_webapps) > 0:
    backend_id = mock_backend_pool if len(mock_backend_pool) > 1 else mock_webapps[0].get("name")

with open("policy.xml", 'r') as policy_xml_file:
    policy_template_xml = policy_xml_file.read()
    policy_xml = policy_template_xml.replace("{backend-id}", backend_id)
    policy_xml_file.close()
open("policy.xml", 'w').write(policy_xml)

bicep_parameters = {
  "$schema": "https://schema.management.azure.com/schemas/2019-04-01/deploymentParameters.json#",
  "contentVersion": "1.0.0.0",
  "parameters": {
    "mockWebApps": { "value": mock_webapps },
    "mockBackendPoolName": { "value": mock_backend_pool },
    "openAIBackendPoolName": { "value": openai_backend_pool },
    "openAIConfig": { "value": openai_resources },
    "openAIDeploymentName": { "value": openai_deployment_name },
    "openAISku": { "value": openai_resources_sku },
    "openAIModelName": { "value": openai_model_name },
    "openAIModelVersion": { "value": openai_model_version },
    "openAIAPISpecURL": { "value": openai_specification_url },
    "apimResourceName": { "value": apim_resource_name},
    "apimResourceLocation": { "value": apim_resource_location},
    "apimSku": { "value": apim_resource_sku},
    "logAnalyticsName": { "value": log_analytics_name },
    "applicationInsightsName": { "value": app_insights_name }
  }
}
with open('params.json', 'w') as bicep_parameters_file:
    bicep_parameters_file.write(json.dumps(bicep_parameters))

! az deployment group create --name {deployment_name} --resource-group {resource_group_name} --template-file "main.bicep" --parameters "params.json"

open("policy.xml", 'w').write(policy_template_xml)
# Out:
# {
#   "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.Resources/deployments/06-built-in-logging",
#   "location": null,
#   "name": "06-built-in-logging",
#   "properties": {
#     "correlationId": "bc319ac6-94c0-4837-aba6-13b6edca6674",
#     "debugSetting": null,
#     "dependencies": [
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/apis/openai",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "apim0L6-pkburuetlvugw/openai",
#         "resourceType": "Microsoft.ApiManagement/service/apis"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/apis/openai",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/apis/openai/policies/policy",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "apim0L6-pkburuetlvugw/openai/policy",
#         "resourceType": "Microsoft.ApiManagement/service/apis/policies"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/backends/openai1",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw/openai1",
#             "resourceType": "Microsoft.ApiManagement/service/backends"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/backends/openai2",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw/openai2",
#             "resourceType": "Microsoft.ApiManagement/service/backends"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/backends/openai-backend-pool",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "apim0L6-pkburuetlvugw/openai-backend-pool",
#         "resourceType": "Microsoft.ApiManagement/service/backends"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/apis/openai",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/subscriptions/openai-subscription",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "apim0L6-pkburuetlvugw/openai-subscription",
#         "resourceType": "Microsoft.ApiManagement/service/subscriptions"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.OperationalInsights/workspaces/workspace-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "workspace-pkburuetlvugw",
#             "resourceType": "Microsoft.OperationalInsights/workspaces"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.Insights/components/insights-pkburuetlvugw",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "insights-pkburuetlvugw",
#         "resourceType": "Microsoft.Insights/components"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.Insights/components/insights-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "insights-pkburuetlvugw",
#             "resourceType": "Microsoft.Insights/components"
#           },
#           {
#             "apiVersion": "2020-02-02",
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.Insights/components/insights-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "insights-pkburuetlvugw",
#             "resourceType": "Microsoft.Insights/components"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/loggers/apim-logger",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "apim0L6-pkburuetlvugw/apim-logger",
#         "resourceType": "Microsoft.ApiManagement/service/loggers"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/apis/openai",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/loggers/apim-logger",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw/apim-logger",
#             "resourceType": "Microsoft.ApiManagement/service/loggers"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/apis/openai/diagnostics/applicationinsights",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "apim0L6-pkburuetlvugw/openai/applicationinsights",
#         "resourceType": "Microsoft.ApiManagement/service/apis/diagnostics"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.Insights/components/insights-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "insights-pkburuetlvugw",
#             "resourceType": "Microsoft.Insights/components"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.Insights/workbooks/d8969cfa-b3dd-5222-9568-eb8da7c943ea",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "d8969cfa-b3dd-5222-9568-eb8da7c943ea",
#         "resourceType": "Microsoft.Insights/workbooks"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai1-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "openai1-pkburuetlvugw",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai1-pkburuetlvugw/deployments/gpt-35-turbo",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "openai1-pkburuetlvugw/gpt-35-turbo",
#         "resourceType": "Microsoft.CognitiveServices/accounts/deployments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai2-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "openai2-pkburuetlvugw",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai2-pkburuetlvugw/deployments/gpt-35-turbo",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "openai2-pkburuetlvugw/gpt-35-turbo",
#         "resourceType": "Microsoft.CognitiveServices/accounts/deployments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai1-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "openai1-pkburuetlvugw",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2023-05-01-preview",
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai1-pkburuetlvugw/providers/Microsoft.Authorization/roleAssignments/e3dffb64-982f-5bfa-94f1-423423ddfc8e",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "e3dffb64-982f-5bfa-94f1-423423ddfc8e",
#         "resourceType": "Microsoft.Authorization/roleAssignments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai2-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "openai2-pkburuetlvugw",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2023-05-01-preview",
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai2-pkburuetlvugw/providers/Microsoft.Authorization/roleAssignments/d512618c-b589-59c2-81a6-57f360d8bf82",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "d512618c-b589-59c2-81a6-57f360d8bf82",
#         "resourceType": "Microsoft.Authorization/roleAssignments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai1-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "openai1-pkburuetlvugw",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2021-10-01",
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai1-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "openai1-pkburuetlvugw",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/backends/openai1",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "apim0L6-pkburuetlvugw/openai1",
#         "resourceType": "Microsoft.ApiManagement/service/backends"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "apim0L6-pkburuetlvugw",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai2-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "openai2-pkburuetlvugw",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2021-10-01",
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai2-pkburuetlvugw",
#             "resourceGroup": "lab-ai-gateway-03456",
#             "resourceName": "openai2-pkburuetlvugw",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/backends/openai2",
#         "resourceGroup": "lab-ai-gateway-03456",
#         "resourceName": "apim0L6-pkburuetlvugw/openai2",
#         "resourceType": "Microsoft.ApiManagement/service/backends"
#       }
#     ],
#     "duration": "PT1M9.2472786S",
#     "error": null,
#     "mode": "Incremental",
#     "onErrorDeployment": null,
#     "outputResources": [
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/apis/openai",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/apis/openai/diagnostics/applicationinsights",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/apis/openai/policies/policy",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/backends/openai1",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/backends/openai2",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/backends/openai-backend-pool",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/loggers/apim-logger",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.ApiManagement/service/apim0L6-pkburuetlvugw/subscriptions/openai-subscription",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai1-pkburuetlvugw",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai1-pkburuetlvugw/deployments/gpt-35-turbo",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai1-pkburuetlvugw/providers/Microsoft.Authorization/roleAssignments/e3dffb64-982f-5bfa-94f1-423423ddfc8e",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai2-pkburuetlvugw",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai2-pkburuetlvugw/deployments/gpt-35-turbo",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.CognitiveServices/accounts/openai2-pkburuetlvugw/providers/Microsoft.Authorization/roleAssignments/d512618c-b589-59c2-81a6-57f360d8bf82",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.Insights/components/insights-pkburuetlvugw",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.Insights/workbooks/d8969cfa-b3dd-5222-9568-eb8da7c943ea",
#         "resourceGroup": "lab-ai-gateway-03456"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-ai-gateway-03456/providers/Microsoft.OperationalInsights/workspaces/workspace-pkburuetlvugw",
#         "resourceGroup": "lab-ai-gateway-03456"
#       }
#     ],
#     "outputs": {
#       "apimResourceGatewayURL": {
#         "type": "String",
#         "value": "https://apim0l6-pkburuetlvugw.azure-api.net"
#       },
#       "apimSubscriptionKey": {
#         "type": "String",
#         "value": "61e4d43bb8dd40f5a16760b4aecc02e9"
#       },
#       "applicationInsightsAppId": {
#         "type": "String",
#         "value": "b40fda72-d480-4d77-b146-f5b41e5175b3"
#       },
#       "logAnalyticsWorkspaceId": {
#         "type": "String",
#         "value": "e7633509-3b40-43e9-b136-e8e4d7288033"
#       }
#     },
#     "parameters": {
#       "apiDiagnosticsLogBytes": {
#         "type": "Int",
#         "value": 8192
#       },
#       "apimLoggerDescription": {
#         "type": "String",
#         "value": "APIM Logger for OpenAI API"
#       },
#       "apimLoggerName": {
#         "type": "String",
#         "value": "apim-logger"
#       },
#       "apimPublisherEmail": {
#         "type": "String",
#         "value": "noreply@microsoft.com"
#       },
#       "apimPublisherName": {
#         "type": "String",
#         "value": "Microsoft"
#       },
#       "apimResourceLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "apimResourceName": {
#         "type": "String",
#         "value": "apim0L6"
#       },
#       "apimSku": {
#         "type": "String",
#         "value": "Basicv2"
#       },
#       "apimSkuCount": {
#         "type": "Int",
#         "value": 1
#       },
#       "applicationInsightsLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "applicationInsightsName": {
#         "type": "String",
#         "value": "insights"
#       },
#       "logAnalyticsLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "logAnalyticsName": {
#         "type": "String",
#         "value": "workspace"
#       },
#       "mockBackendPoolDescription": {
#         "type": "String",
#         "value": "Load balancer for multiple OpenAI Mocking endpoints"
#       },
#       "mockBackendPoolName": {
#         "type": "String",
#         "value": "mock-backend-pool"
#       },
#       "mockWebApps": {
#         "type": "Array",
#         "value": [
#           {
#             "endpoint": "https://openaimock1.azurewebsites.net",
#             "name": "openaimock1"
#           },
#           {
#             "endpoint": "https://openaimock2.azurewebsites.net",
#             "name": "openaimock2"
#           }
#         ]
#       },
#       "openAIAPIDescription": {
#         "type": "String",
#         "value": "Azure OpenAI API inferencing API"
#       },
#       "openAIAPIDisplayName": {
#         "type": "String",
#         "value": "OpenAI"
#       },
#       "openAIAPIName": {
#         "type": "String",
#         "value": "openai"
#       },
#       "openAIAPIPath": {
#         "type": "String",
#         "value": "openai"
#       },
#       "openAIAPISpecURL": {
#         "type": "String",
#         "value": "https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/2024-02-01/inference.json"
#       },
#       "openAIBackendPoolDescription": {
#         "type": "String",
#         "value": "Load balancer for multiple OpenAI endpoints"
#       },
#       "openAIBackendPoolName": {
#         "type": "String",
#         "value": "openai-backend-pool"
#       },
#       "openAIConfig": {
#         "type": "Array",
#         "value": [
#           {
#             "location": "swedencentral",
#             "name": "openai1"
#           },
#           {
#             "location": "francecentral",
#             "name": "openai2"
#           }
#         ]
#       },
#       "openAIDeploymentName": {
#         "type": "String",
#         "value": "gpt-35-turbo"
#       },
#       "openAIModelCapacity": {
#         "type": "Int",
#         "value": 20
#       },
#       "openAIModelName": {
#         "type": "String",
#         "value": "gpt-35-turbo"
#       },
#       "openAIModelVersion": {
#         "type": "String",
#         "value": "0613"
#       },
#       "openAISku": {
#         "type": "String",
#         "value": "S0"
#       },
#       "openAISubscriptionDescription": {
#         "type": "String",
#         "value": "OpenAI Subscription"
#       },
#       "openAISubscriptionName": {
#         "type": "String",
#         "value": "openai-subscription"
#       },
#       "workbookDisplayName": {
#         "type": "String",
#         "value": "OpenAI Usage Analysis"
#       },
#       "workbookLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "workbookName": {
#         "type": "String",
#         "value": "OpenAIUsageAnalysis"
#       }
#     },
#     "parametersLink": null,
#     "providers": [
#       {
#         "id": null,
#         "namespace": "Microsoft.ApiManagement",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "service",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis/policies",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/backends",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/subscriptions",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/loggers",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis/diagnostics",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.OperationalInsights",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "workspaces",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.Insights",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "components",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "workbooks",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.CognitiveServices",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "swedencentral",
#               "francecentral"
#             ],
#             "properties": null,
#             "resourceType": "accounts",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "accounts/deployments",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.Authorization",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "roleAssignments",
#             "zoneMappings": null
#           }
#         ]
#       }
#     ],
#     "provisioningState": "Succeeded",
#     "templateHash": "16756995089715035937",
#     "templateLink": null,
#     "timestamp": "2024-05-10T07:24:22.291364+00:00",
#     "validatedResources": null
#   },
#   "resourceGroup": "lab-ai-gateway-03456",
#   "tags": null,
#   "type": "Microsoft.Resources/deployments"
# }
# WARNING: A new Bicep release is available: v0.27.1. Upgrade now by running "az bicep upgrade".
# WARNING: c:\GIT\GitHub\mmcr\AI-Gateway\labs\06-built-in-logging\main.bicep(159,22) : Warning BCP081: Resource type "Microsoft.ApiManagement/service@2023-05-01-preview" does not have types available.
#
# c:\GIT\GitHub\mmcr\AI-Gateway\labs\06-built-in-logging\main.bicep(186,14) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/apis@2023-05-01-preview" does not have types available.
#
# c:\GIT\GitHub\mmcr\AI-Gateway\labs\06-built-in-logging\main.bicep(217,24) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/backends@2023-05-01-preview" does not have types available.
#
# c:\GIT\GitHub\mmcr\AI-Gateway\labs\06-built-in-logging\main.bicep(248,22) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/backends@2023-05-01-preview" does not have types available.
#
# c:\GIT\GitHub\mmcr\AI-Gateway\labs\06-built-in-logging\main.bicep(279,28) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/backends@2023-05-01-preview" does not have types available.
#
# c:\GIT\GitHub\mmcr\AI-Gateway\labs\06-built-in-logging\main.bicep(296,26) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/backends@2023-05-01-preview" does not have types available.
#
# c:\GIT\GitHub\mmcr\AI-Gateway\labs\06-built-in-logging\main.bicep(313,27) : Warning BCP081: Resource type "Microsoft.ApiManagement/service/subscriptions@2023-05-01-preview" does not have types available.
# 623

# %% [markdown]
# ### 3️⃣ Get the deployment outputs
#
# We are now at the stage where we only need to retrieve the gateway URL and the subscription before we are ready for testing.

# %%
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimSubscriptionKey.value -o tsv
apim_subscription_key = deployment_stdout.n
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimResourceGatewayURL.value -o tsv
apim_resource_gateway_url = deployment_stdout.n
print("👉🏻 API Gateway URL: ", apim_resource_gateway_url)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.logAnalyticsWorkspaceId.value -o tsv
workspace_id = deployment_stdout.n
print("👉🏻 Workspace ID: ", workspace_id)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.applicationInsightsAppId.value -o tsv
app_id = deployment_stdout.n
print("👉🏻 App ID: ", app_id)
# Out:
# 👉🏻 API Gateway URL:  https://apim0l6-pkburuetlvugw.azure-api.net
# 👉🏻 Workspace ID:  e7633509-3b40-43e9-b136-e8e4d7288033
# 👉🏻 App ID:  b40fda72-d480-4d77-b146-f5b41e5175b3

# %% [markdown]
# ### 🧪 Test the API using a direct HTTP call
# Requests is an elegant and simple HTTP library for Python that will be used here to make raw API requests and inspect the responses.

# %%
import time
runs = 2
sleep_time_ms = 1000

url = apim_resource_gateway_url + "/openai/deployments/" + openai_deployment_name + "/chat/completions?api-version=" + openai_api_version

for i in range(runs):
    print("▶️ Run: ", i+1)
    if len(openai_resources) > 0:
        messages={"messages":[
            {"role": "system", "content": "You are a sarcastic unhelpful assistant."},
            {"role": "user", "content": "Can you tell me the time, please?"}
        ]}
    elif len(mock_webapps) > 0:
        messages={
            "messages": [
                {
                    "role": "system", 
                    "content": {
                        "simulation": {
                            "default": {"response_status_code": 200, "wait_time_ms": 0},
                            "openaimock1.azurewebsites.net": {"response_status_code": 429}
                        }
                    }
                }
            ]
        }
    response = requests.post(url, headers = {'api-key':apim_subscription_key}, json = messages)
    print("status code: ", response.status_code)
    print("headers ", response.headers)
    print("x-ms-region: ", response.headers.get("x-ms-region")) # this header is useful to determine the region of the backend that served the request
    if (response.status_code == 200):
        data = json.loads(response.text)
        print("response: ", data.get("choices")[0].get("message").get("content"))
    else:
        print(response.text)
    time.sleep(sleep_time_ms/1000)
# Out:
# ▶️ Run:  1
# status code:  200
# headers  {'Content-Length': '934', 'Content-Type': 'application/json', 'Date': 'Fri, 10 May 2024 07:27:24 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': '15b0797e-ca14-4923-80c1-eefb76afdce5', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'France Central', 'x-ratelimit-remaining-requests': '18', 'x-ratelimit-remaining-tokens': '19968', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': 'e6cc90d5-b12f-44ee-80ca-290d66741817', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd032-20240426171512', 'Request-Context': 'appId=cid-v1:b40fda72-d480-4d77-b146-f5b41e5175b3'}
# x-ms-region:  France Central
# response:  Oh sure, let me just consult my psychic abilities to magically know what time it is. Or, you know, you could just look at a clock. It's not rocket science.
# ▶️ Run:  2
# status code:  200
# headers  {'Content-Length': '954', 'Content-Type': 'application/json', 'Date': 'Fri, 10 May 2024 07:27:26 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': 'cd0bda0e-8e60-4743-979e-ea37736dd7d3', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'Sweden Central', 'x-ratelimit-remaining-requests': '18', 'x-ratelimit-remaining-tokens': '19968', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': 'fcc65acd-3adf-42e8-b991-498102e7cf2f', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd1254-20240430194945', 'Request-Context': 'appId=cid-v1:b40fda72-d480-4d77-b146-f5b41e5175b3'}
# x-ms-region:  Sweden Central
# response:  Oh sure, I'd be delighted to do something as simple and menial as telling you the time. But oh wait, I forgot! I'm actually incapable of performing that basic function. Sorry!

# %% [markdown]
# ### 🧪 Test the API using the Azure OpenAI Python SDK
# OpenAPI provides a widely used [Python library](https://github.com/openai/openai-python). The library includes type definitions for all request params and response fields. The goal of this test is to assert that APIM can seamlessly proxy requests to OpenAI without disrupting its functionality.
# - Note: run ```pip install openai``` in a terminal before executing this step.

# %%
import time
runs = 2
sleep_time_ms = 1000

for i in range(runs):
    print("▶️ Run: ", i+1)
    from openai import AzureOpenAI
    if len(openai_resources) > 0:
        messages=[
            {"role": "system", "content": "You are a sarcastic unhelpful assistant."},
            {"role": "user", "content": "Can you tell me the time, please?"}
        ]
    elif len(mock_webapps) > 0:
        messages=[
                {
                    "role": "system", 
                    "content": {
                        "simulation": {
                            "default": {"response_status_code": 200, "wait_time_ms": 0},
                            "openaimock1.azurewebsites.net": {"response_status_code": 429}
                        }
                    }
                }
            ]
    client = AzureOpenAI(
        azure_endpoint=apim_resource_gateway_url,
        api_key=apim_subscription_key,
        api_version=openai_api_version
    )
    response = client.chat.completions.create(model=openai_model_name, messages=messages)
    print(response.choices[0].message.content)
    time.sleep(sleep_time_ms/1000)
# Out:
# ▶️ Run:  1
# Oh, sure. Let me check my crystal ball that magically displays the time. Or you could, you know, just look at your phone or a clock like a normal person. But who needs convenience when you can ask me for the time instead? It's not like I have better things to do.
# ▶️ Run:  2
# Oh, I would love to assist you with that, but I really don't have the capability to tell time. I mean, who needs to know what time it is these days anyway? It's not like it's important to be punctual or anything.

# %% [markdown]
# ### 🔍 Analyze Application Insights requests
#
# With this query you can get the request and response details including the prompt and the OpenAI completion. It also returns token counters.

# %%
import pandas as pd

query = "\"" + "requests  \
| project timestamp, duration, customDimensions \
| extend duration = round(duration, 2) \
| extend parsedCustomDimensions = parse_json(customDimensions) \
| extend apiName = tostring(parsedCustomDimensions.['API Name']) \
| extend apimSubscription = tostring(parsedCustomDimensions.['Subscription Name']) \
| extend userAgent = tostring(parsedCustomDimensions.['Request-User-agent']) \
| extend request_json = tostring(parsedCustomDimensions.['Request-Body']) \
| extend request = parse_json(request_json) \
| extend model = tostring(request.['model']) \
| extend messages = tostring(request.['messages']) \
| extend region = tostring(parsedCustomDimensions.['Response-x-ms-region']) \
| extend remainingTokens = tostring(parsedCustomDimensions.['Response-x-ratelimit-remaining-tokens']) \
| extend remainingRequests = tostring(parsedCustomDimensions.['Response-x-ratelimit-remaining-requests']) \
| extend response_json = tostring(parsedCustomDimensions.['Response-Body']) \
| extend response = parse_json(response_json) \
| extend promptTokens = tostring(response.['usage'].['prompt_tokens']) \
| extend completionTokens = tostring(response.['usage'].['completion_tokens']) \
| extend totalTokens = tostring(response.['usage'].['total_tokens']) \
| extend completion = tostring(response.['choices'][0].['message'].['content']) \
| project timestamp, apiName, apimSubscription, duration, userAgent, model, messages, completion, region, promptTokens, completionTokens, totalTokens, remainingTokens, remainingRequests \
| order by timestamp desc" + "\""

result_stdout = !  az monitor app-insights query --app {app_id} --analytics-query {query} 
result = json.loads(result_stdout.n)

table = result.get('tables')[0]
pd.DataFrame(table.get("rows"), columns=[col.get("name") for col in table.get('columns')])
# Out:
#                       timestamp apiName     apimSubscription  duration  \
# 0  2024-05-10T07:27:34.0650048Z  openai  openai-subscription    861.14
# 1  2024-05-10T07:27:31.1293039Z  openai  openai-subscription   1496.00
# 2  2024-05-10T07:27:25.6296204Z  openai  openai-subscription    664.82
# 3  2024-05-10T07:27:23.0916628Z  openai  openai-subscription   1075.81
# 4  2024-05-10T07:27:18.0528465Z  openai  openai-subscription   1022.47
# 5  2024-05-10T07:27:15.3180967Z  openai  openai-subscription   1241.12
# 6  2024-05-10T07:25:04.5575002Z  openai  openai-subscription    709.98
# 7  2024-05-10T07:25:01.7883269Z  openai  openai-subscription   1191.07
# 8   2024-05-10T07:24:58.106132Z  openai  openai-subscription    601.70
# 9  2024-05-10T07:24:53.8907146Z  openai  openai-subscription   2775.03
#
#                    userAgent         model  \
# 0  AzureOpenAI/Python 1.27.0  gpt-35-turbo
# 1  AzureOpenAI/Python 1.27.0  gpt-35-turbo
# 2     python-requests/2.31.0
# 3     python-requests/2.31.0
# 4     python-requests/2.31.0
# 5     python-requests/2.31.0
# 6  AzureOpenAI/Python 1.27.0  gpt-35-turbo
# 7  AzureOpenAI/Python 1.27.0  gpt-35-turbo
# 8     python-requests/2.31.0
# 9     python-requests/2.31.0
#
#                                             messages  \
# 0  [{"role":"system","content":"You are a sarcast...
# 1  [{"role":"system","content":"You are a sarcast...
# 2  [{"role":"system","content":"You are a sarcast...
# 3  [{"role":"system","content":"You are a sarcast...
# 4  [{"role":"system","content":"You are a sarcast...
# 5  [{"role":"system","content":"You are a sarcast...
# 6  [{"role":"system","content":"You are a sarcast...
# 7  [{"role":"system","content":"You are a sarcast...
# 8  [{"role":"system","content":"You are a sarcast...
# 9  [{"role":"system","content":"You are a sarcast...
#
#                                           completion          region  \
# 0  Oh, I would love to assist you with that, but ...  Sweden Central
# 1  Oh, sure. Let me check my crystal ball that ma...  France Central
# 2  Oh sure, I'd be delighted to do something as s...  Sweden Central
# 3  Oh sure, let me just consult my psychic abilit...  France Central
# 4  Oh, sure. Because telling time is such a compl...  Sweden Central
# 5  Oh, I'm so sorry, I can't do that. I'm just a ...  France Central
# 6  Oh, I'm sorry, I must have forgotten where I p...  Sweden Central
# 7  Oh, I would love to fulfill your trivial reque...  France Central
# 8  Oh sure, let me drop everything I'm doing just...  Sweden Central
# 9  Oh, absolutely! Let me just give you the most ...  France Central
#
#   promptTokens completionTokens totalTokens remainingTokens remainingRequests
# 0           30               52          82           19952                18
# 1           30               61          91           19952                18
# 2           30               40          70           19968                18
# 3           30               37          67           19968                18
# 4           30               63          93           19984                19
# 5           30               51          81           19984                19
# 6           30               44          74           19968                18
# 7           30               41          71           19968                18
# 8           30               23          53           19984                19
# 9           30               38          68           19984                19

# %% [markdown]
# ### 🔍 Open the workbook in the Azure Portal
#
# Go to the application insights resource and under the Monitoring section select the Workbooks blade. You should see the OpenAI Usage Analysis workbook with the above query and some others to check token counts, performance, failures, etc.

# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.
# Use the [clean-up-resources notebook](clean-up-resources.ipynb) for that.
