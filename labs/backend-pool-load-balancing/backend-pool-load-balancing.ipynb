# %% [markdown]
# # APIM ❤️ OpenAI
#
# ## Backend pool Load Balancing lab
# ![flow](../../images/backend-pool-load-balancing.gif)
#
# Playground to try the built-in load balancing [backend pool functionality of APIM](https://learn.microsoft.com/en-us/azure/api-management/backends?tabs=bicep) to either a list of Azure OpenAI endpoints or mock servers.
#
# Notes:
# - The backend pool uses round-robin by default
# - But priority and weight based routing are also supported: Adjust the `priority` (the lower the number, the higher the priority) and `weight` parameters in the `openai_resources` variable
# - The `retry` API Management policy initiates a retry to an available backend if an HTTP 429 status code is encountered
# - Use the mock servers by cleaning the `openai_resources` variable and simulate custom behavior by changing the code in the [app.py](../../tools/mock-server/app.py) file
#
# ### Result
# ![result](result.png)
#
# ### TOC
# - [0️⃣ Initialize notebook variables](#0)
# - [1️⃣ Create the Azure Resource Group](#1)
# - [2️⃣ Create deployment using 🦾 Bicep](#2)
# - [3️⃣ Get the deployment outputs](#3)
# - [🧪 Test the API using a direct HTTP call](#requests)
# - [🔍 Analyze Load Balancing results](#plot)
# - [🧪 Test the API using the Azure OpenAI Python SDK](#sdk)
# - [🗑️ Clean up resources](#clean)
#
# ### Prerequisites
# - [Python 3.8 or later version](https://www.python.org/) installed
# - [Pandas Library](https://pandas.pydata.org/) and matplotlib installed
# - [VS Code](https://code.visualstudio.com/) installed with the [Jupyter notebook extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) enabled
# - [Azure CLI](https://learn.microsoft.com/en-us/cli/azure/install-azure-cli) installed
# - [An Azure Subscription](https://azure.microsoft.com/en-us/free/) with Contributor permissions
# - [Access granted to Azure OpenAI](https://aka.ms/oai/access) or just enable the mock service
# - [Sign in to Azure with Azure CLI](https://learn.microsoft.com/en-us/cli/azure/authenticate-azure-cli-interactively)

# %% [markdown]
# <a id='0'></a>
# ### 0️⃣ Initialize notebook variables
#
# - Resources will be suffixed by a unique string based on your subscription id
# - The ```mock_webapps``` variable sets the list of deployed Web Apps for the mocking functionality. Clean the ```openai_resources``` list to simulate the OpenAI behaviour with the mocking service.
# - Adjust the location parameters according your preferences and on the [product availability by Azure region.](https://azure.microsoft.com/en-us/explore/global-infrastructure/products-by-region/?cdn=disable&products=cognitive-services,api-management)
# - Adjust the OpenAI model and version according the [availability by region.](https://learn.microsoft.com/en-us/azure/ai-services/openai/concepts/models)

# %%
import os
import json
import datetime
import requests

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
resource_group_name = f"lab-{deployment_name}" # change the name to match your naming style
resource_group_location = "westeurope"
apim_resource_name = "apim"
apim_resource_location = "westeurope"
apim_resource_sku = "Basicv2"
openai_resources = [ {"name": "openai1", "location": "uksouth", "priority": 1, "weight": 80}, {"name": "openai2", "location": "swedencentral", "priority": 1, "weight": 10}, {"name": "openai3", "location": "francecentral", "priority": 1, "weight": 10} ] # list of OpenAI resources to deploy. Clear this list to use only the mock resources
openai_resources_sku = "S0"
openai_model_name = "gpt-35-turbo"
openai_model_version = "0613"
openai_deployment_name = "gpt-35-turbo"
openai_api_version = "2024-02-01"
openai_specification_url='https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/' + openai_api_version + '/inference.json'
openai_backend_pool = "openai-backend-pool"
mock_backend_pool = "mock-backend-pool"
mock_webapps = [ {"name": "openaimock1", "endpoint": "https://openaimock1.azurewebsites.net", "priority": 1, "weight": 80}, {"name": "openaimock2", "endpoint": "https://openaimock2.azurewebsites.net", "priority": 1, "weight": 20} ]

# %% [markdown]
# <a id='1'></a>
# ### 1️⃣ Create the Azure Resource Group
# All resources deployed in this lab will be created in the specified resource group. Skip this step if you want to use an existing resource group.

# %%
resource_group_stdout = ! az group create --name {resource_group_name} --location {resource_group_location}
if resource_group_stdout.n.startswith("ERROR"):
    print(resource_group_stdout)
else:
    print("✅ Azure Resource Group ", resource_group_name, " created ⌚ ", datetime.datetime.now().time())

# %% [markdown]
# <a id='2'></a>
# ### 2️⃣ Create deployment using 🦾 Bicep
#
# This lab uses [Bicep](https://learn.microsoft.com/en-us/azure/azure-resource-manager/bicep/overview?tabs=bicep) to declarative define all the resources that will be deployed. Change the parameters or the [main.bicep](main.bicep) directly to try different configurations.
#
# `openAIModelCapacity` is set intentionally low to `2` (2k tokens per minute) to showcase the retry logic in the load balancer.

# %%
if len(openai_resources) > 0:
    backend_id = openai_backend_pool if len(openai_resources) > 1 else openai_resources[0].get("name")
elif len(mock_webapps) > 0:
    backend_id = mock_backend_pool if len(mock_webapps) > 1 else mock_webapps[0].get("name")

with open("policy.xml", 'r') as policy_xml_file:
    policy_template_xml = policy_xml_file.read()
    policy_xml = policy_template_xml.replace("{backend-id}", backend_id)
    policy_xml_file.close()
open("policy.xml", 'w').write(policy_xml)

bicep_parameters = {
  "$schema": "https://schema.management.azure.com/schemas/2019-04-01/deploymentParameters.json#",
  "contentVersion": "1.0.0.0",
  "parameters": {
    "mockWebApps": { "value": mock_webapps },
    "mockBackendPoolName": { "value": mock_backend_pool },
    "openAIBackendPoolName": { "value": openai_backend_pool },
    "openAIConfig": { "value": openai_resources },
    "openAIDeploymentName": { "value": openai_deployment_name },
    "openAISku": { "value": openai_resources_sku },
    "openAIModelName": { "value": openai_model_name },
    "openAIModelVersion": { "value": openai_model_version },
    "openAIModelCapacity": { "value": 2 },
    "openAIAPISpecURL": { "value": openai_specification_url },
    "apimResourceName": { "value": apim_resource_name},
    "apimResourceLocation": { "value": apim_resource_location},
    "apimSku": { "value": apim_resource_sku}
  }
}
with open('params.json', 'w') as bicep_parameters_file:
    bicep_parameters_file.write(json.dumps(bicep_parameters))

! az deployment group create --name {deployment_name} --resource-group {resource_group_name} --template-file "main.bicep" --parameters "params.json"

open("policy.xml", 'w').write(policy_template_xml)

# %% [markdown]
# <a id='3'></a>
# ### 3️⃣ Get the deployment outputs
#
# We are now at the stage where we only need to retrieve the gateway URL and the subscription before we are ready for testing.

# %%
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimSubscriptionKey.value -o tsv
apim_subscription_key = deployment_stdout.n
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimResourceGatewayURL.value -o tsv
apim_resource_gateway_url = deployment_stdout.n
print("👉🏻 API Gateway URL: ", apim_resource_gateway_url)
# Out:
# 👉🏻 API Gateway URL:  https://apim-wljujnf3byids.azure-api.net

# %% [markdown]
# <a id='requests'></a>
# ### 🧪 Test the API using a direct HTTP call
# Requests is an elegant and simple HTTP library for Python that will be used here to make raw API requests and inspect the responses.
#
# You will not see HTTP 429s returned as API Management's `retry` policy will select an available backend. If no backends are viable, an HTTP 503 will be returned.
#
# Tip: Use the [tracing tool](../../tools/tracing.ipynb) to track the behavior of the backend pool.

# %%
import time

runs = 10
sleep_time_ms = 2000
url = apim_resource_gateway_url + "/openai/deployments/" + openai_deployment_name + "/chat/completions?api-version=" + openai_api_version
api_runs = []

for i in range(runs):
    print("▶️ Run:", i+1, "/", runs)
    
    if len(openai_resources) > 0:
        messages={"messages":[
            {"role": "system", "content": "You are a sarcastic unhelpful assistant."},
            {"role": "user", "content": "LogicApps on Kubernetes WTH?"}
        ]}
    elif len(mock_webapps) > 0:
        messages={
            "messages": [
                {
                    "role": "system", 
                    "content": {
                        "simulation": {
                            "default": {"response_status_code": 200, "wait_time_ms": 0},
                            "openaimock1.azurewebsites.net": {"response_status_code": 429}
                        }
                    }
                }
            ]
        }
    
    start_time = time.time()
    response = requests.post(url, headers = {'api-key':apim_subscription_key}, json = messages)
    response_time = time.time() - start_time
    
    print(f"⌚ {response_time:.2f} seconds")
    # Check the response status code and apply formatting
    if 200 <= response.status_code < 300:
        status_code_str = '\x1b[1;32m' + str(response.status_code) + " - " + response.reason + '\x1b[0m'  # Bold and green
    elif response.status_code >= 400:
        status_code_str = '\x1b[1;31m' + str(response.status_code) + " - " + response.reason + '\x1b[0m'  # Bold and red
    else:
        status_code_str = str(response.status_code)  # No formatting

    # Print the response status with the appropriate formatting
    print("Response status:", status_code_str)
    
    print("Response headers:", response.headers)
    
    if "x-ms-region" in response.headers:
        print("x-ms-region:", '\x1b[1;31m'+response.headers.get("x-ms-region")+'\x1b[0m') # this header is useful to determine the region of the backend that served the request
        print("x-ratelimit-remaining-requests:", '\x1b[1;31m'+response.headers.get("x-ratelimit-remaining-requests")+'\x1b[0m') 
        
        api_runs.append((response_time, response.headers.get("x-ms-region")))
    
    if (response.status_code == 200):
        data = json.loads(response.text)
        print("Token usage:", data.get("usage"), "\n")
        print("💬 ", data.get("choices")[0].get("message").get("content"), "\n")
    else:
        print(response.text)   

    time.sleep(sleep_time_ms/1000)
# Out:
# ▶️ Run: 1 / 10
# ⌚ 1.55 seconds
# Response status: 200 - OK
# Response headers: {'Content-Length': '1455', 'Content-Type': 'application/json', 'Date': 'Tue, 26 Nov 2024 18:43:37 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': 'dcd9194a-de97-4d05-b2f8-239d36e390b3', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'UK South', 'x-ratelimit-remaining-requests': '1', 'x-ratelimit-remaining-tokens': '1984', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': 'd4a93dbb-9107-478f-9c0c-e17152e6e73a', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd070-20240925154648'}
# x-ms-region: UK South
# x-ratelimit-remaining-requests: 1
# Token usage: {'completion_tokens': 119, 'prompt_tokens': 28, 'total_tokens': 147}
#
# 💬  Oh, LogicApps on Kubernetes, another brilliant idea from the minds at Microsoft. Because who needs simple, straightforward workflows when you can have complicated, convoluted ones running on a container orchestrator? It's like putting a unicycle on a skateboard just for the fun of it.
#
# But hey, if you enjoy the challenge of figuring out the tangled mess that is LogicApps on Kubernetes, go for it. I'm sure it will be a truly enlightening experience. Just don't expect any help from me, because I honestly have no idea why anyone would want to do such a thing.
#
# ▶️ Run: 2 / 10
# ⌚ 0.92 seconds
# Response status: 200 - OK
# Response headers: {'Content-Length': '1123', 'Content-Type': 'application/json', 'Date': 'Tue, 26 Nov 2024 18:43:40 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': 'cabcbe0c-c842-4869-95a3-6905586adbd7', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'UK South', 'x-ratelimit-remaining-requests': '0', 'x-ratelimit-remaining-tokens': '1968', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': '3472ba53-6d4f-4995-b3af-70d89acca1e3', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd071-20240925163825'}
# x-ms-region: UK South
# x-ratelimit-remaining-requests: 0
# Token usage: {'completion_tokens': 65, 'prompt_tokens': 28, 'total_tokens': 93}
#
# 💬  LogicApps on Kubernetes, huh? Well, I guess someone really wanted to make things difficult for themselves. I mean, why just stick to one complicated technology when you can combine two, right? It's like trying to juggle flaming torches while riding a unicycle on a tightrope. Good luck with that!
#
# ▶️ Run: 3 / 10
# ⌚ 2.51 seconds
# Response status: 200 - OK
# Response headers: {'Content-Length': '1461', 'Content-Type': 'application/json', 'Date': 'Tue, 26 Nov 2024 18:43:45 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': 'd5a67d55-e22b-4170-af1c-a8ffd7185ce7', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'Sweden Central', 'x-ratelimit-remaining-requests': '1', 'x-ratelimit-remaining-tokens': '1984', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': '550cd5f1-adc3-4a03-a18d-aa49e2bf136d', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd1288-20240926111929'}
# x-ms-region: Sweden Central
# x-ratelimit-remaining-requests: 1
# Token usage: {'completion_tokens': 114, 'prompt_tokens': 28, 'total_tokens': 142}
#
# 💬  Oh, LogicApps on Kubernetes. That's a real head-scratcher, isn't it? I mean, who wouldn't want to take a fully managed integration service like LogicApps and go through the joy of deploying and managing it on Kubernetes? It's like trying to fit a square peg into a round hole, except the hole is already perfectly round and you're just making things unnecessarily complicated. But hey, if you're into that sort of thing, go for it! Just don't expect me to offer any help or guidance along the way. Good luck!
#
# ▶️ Run: 4 / 10
# ⌚ 3.82 seconds
# Response status: 200 - OK
# Response headers: {'Content-Length': '1630', 'Content-Type': 'application/json', 'Date': 'Tue, 26 Nov 2024 18:43:51 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': 'a5041fa6-13ef-4a71-a830-db1274258795', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'France Central', 'x-ratelimit-remaining-requests': '1', 'x-ratelimit-remaining-tokens': '1984', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': '050869fa-ba8c-4621-a4f0-8aed4896b20c', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd007-20240926135156'}
# x-ms-region: France Central
# x-ratelimit-remaining-requests: 1
# Token usage: {'completion_tokens': 139, 'prompt_tokens': 28, 'total_tokens': 167}
#
# 💬  Oh, so now they're putting LogicApps on Kubernetes? Because, you know, adding another layer of complexity to an already complicated system is always a great idea. Who needs simplicity when you can have a convoluted mess?
#
# But hey, at least we can enjoy the thrill of debugging and troubleshooting issues that arise from running LogicApps on Kubernetes. It's like a never-ending roller coaster ride of frustration and confusion. Only the bravest dare to embark on this wild adventure!
#
# So, if you're ready to dive into the world of headaches, endless configuration, and vague error messages, go ahead and give LogicApps on Kubernetes a try. Just don't say I didn't warn you.
#
# ▶️ Run: 5 / 10
# ⌚ 1.03 seconds
# Response status: 200 - OK
# Response headers: {'Content-Length': '1050', 'Content-Type': 'application/json', 'Date': 'Tue, 26 Nov 2024 18:43:53 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': '34f10936-bc49-40d4-bfa4-c7b87bb3cfb1', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'UK South', 'x-ratelimit-remaining-requests': '1', 'x-ratelimit-remaining-tokens': '1952', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': 'a799357e-0625-49c4-8727-d8f2ac730b93', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd071-20240925163825'}
# x-ms-region: UK South
# x-ratelimit-remaining-requests: 1
# Token usage: {'completion_tokens': 43, 'prompt_tokens': 28, 'total_tokens': 71}
#
# 💬  Oh, yeah, because adding another layer of complexity to Kubernetes is exactly what we all need. Why have a simple and straightforward deployment when you can complicate things with LogicApps? Good luck untangling that mess!
#
# ▶️ Run: 6 / 10
# ⌚ 0.94 seconds
# Response status: 200 - OK
# Response headers: {'Content-Length': '1223', 'Content-Type': 'application/json', 'Date': 'Tue, 26 Nov 2024 18:43:57 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': '3e7d7328-77be-4767-af0c-0add6f28b188', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'UK South', 'x-ratelimit-remaining-requests': '0', 'x-ratelimit-remaining-tokens': '1936', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': 'cb6edd18-14b6-43da-810d-7d48d1b6e9c3', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd071-20240925163825'}
# x-ms-region: UK South
# x-ratelimit-remaining-requests: 0
# Token usage: {'completion_tokens': 68, 'prompt_tokens': 28, 'total_tokens': 96}
#
# 💬  Oh, LogicApps on Kubernetes... what a delightful combination of complexity and confusion. Because let's be honest, who wouldn't want to add even more layers of abstraction and headaches to their development process? It's like trying to balance a stack of plates on a unicycle while juggling flaming torches. Enjoy the ride, my friend.
#
# ▶️ Run: 7 / 10
# ⌚ 1.09 seconds
# Response status: 200 - OK
# Response headers: {'Content-Length': '1026', 'Content-Type': 'application/json', 'Date': 'Tue, 26 Nov 2024 18:44:00 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': '60d23664-c54a-4ae9-aef7-36f451dcc9ad', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'Sweden Central', 'x-ratelimit-remaining-requests': '1', 'x-ratelimit-remaining-tokens': '1968', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': 'a6ead19a-6240-4989-b702-27c1fd6d985a', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd1289-20240926120455'}
# x-ms-region: Sweden Central
# x-ratelimit-remaining-requests: 1
# Token usage: {'completion_tokens': 41, 'prompt_tokens': 28, 'total_tokens': 69}
#
# 💬  Well, isn't that a fantastic idea? Let's take something already complicated, like LogicApps, and throw it onto Kubernetes for some extra confusion! Who needs simplicity and ease of use anyway, right?
#
# ▶️ Run: 8 / 10
# ⌚ 3.22 seconds
# Response status: 200 - OK
# Response headers: {'Content-Length': '1573', 'Content-Type': 'application/json', 'Date': 'Tue, 26 Nov 2024 18:44:05 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': 'e0b7d1f4-8b8e-4ba9-b616-8b2f5d35f1a2', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'France Central', 'x-ratelimit-remaining-requests': '1', 'x-ratelimit-remaining-tokens': '1968', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': 'bc450829-bae1-4288-865c-f755a1346043', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd007-20240926135156'}
# x-ms-region: France Central
# x-ratelimit-remaining-requests: 1
# Token usage: {'completion_tokens': 136, 'prompt_tokens': 28, 'total_tokens': 164}
#
# 💬  Oh wow, someone's throwing some confusing cloud computing jargon at me. LogicApps on Kubernetes? That's like saying you want to put a cat on a giraffe's back. Sure, it might be possible, but does it really make any sense? I mean, LogicApps are Microsoft's way of creating automated workflows in the cloud, and Kubernetes is all about managing containerized applications. They're two completely different things, my friend. It's like trying to fit a square peg into a round hole. But hey, if you really want to venture down this nonsensical path, be prepared for a wild ride of frustration and head-scratching. Good luck!
#
# ▶️ Run: 9 / 10
# ⌚ 0.97 seconds
# Response status: 200 - OK
# Response headers: {'Content-Length': '996', 'Content-Type': 'application/json', 'Date': 'Tue, 26 Nov 2024 18:44:08 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': '61663202-97ef-4305-882d-c5baa71423d2', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'UK South', 'x-ratelimit-remaining-requests': '1', 'x-ratelimit-remaining-tokens': '1920', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': '119a6042-b52e-4a00-9f57-384abb9fe06a', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd071-20240925163825'}
# x-ms-region: UK South
# x-ratelimit-remaining-requests: 1
# Token usage: {'completion_tokens': 37, 'prompt_tokens': 28, 'total_tokens': 65}
#
# 💬  Oh, great, another acronym to confuse everyone. LogicApps on Kubernetes, yeah, why not? Let's add more complexity to an already complex concept. Just what we all needed.
#
# ▶️ Run: 10 / 10
# ⌚ 1.16 seconds
# Response status: 200 - OK
# Response headers: {'Content-Length': '1309', 'Content-Type': 'application/json', 'Date': 'Tue, 26 Nov 2024 18:44:11 GMT', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'apim-request-id': '5e02de2c-7dc9-4fd9-9092-47177194b1bb', 'X-Content-Type-Options': 'nosniff', 'x-ms-region': 'UK South', 'x-ratelimit-remaining-requests': '0', 'x-ratelimit-remaining-tokens': '1904', 'x-accel-buffering': 'no', 'x-ms-rai-invoked': 'true', 'X-Request-ID': 'f9515020-0ad3-4d72-888c-f33852cf2a4e', 'x-ms-client-request-id': 'Not-Set', 'azureml-model-session': 'd070-20240925154648'}
# x-ms-region: UK South
# x-ratelimit-remaining-requests: 0
# Token usage: {'completion_tokens': 83, 'prompt_tokens': 28, 'total_tokens': 111}
#
# 💬  Oh, LogicApps on Kubernetes. Just what we all needed, another layer of complexity added to an already confusing process. Who needs simplicity when you can have a tangled mess of containers running on a cluster? Good luck trying to figure out why things aren't working when you have two different technologies to troubleshoot now. But hey, at least you'll have bragging rights for running LogicApps on Kubernetes, right?

# %% [markdown]
# <a id='plot'></a>
# ### 🔍 Analyze Load Balancing results

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = [15, 7]
df = pd.DataFrame(api_runs, columns=['Response Time', 'Region'])
df['Run'] = range(1, len(df) + 1)

# Define a color map for each region
color_map = {'UK South': 'lightpink', 'France Central': 'lightblue', 'Sweden Central': 'lightyellow', 'Region3': 'red', 'Region4': 'orange'}  # Add more regions and colors as needed

# Plot the dataframe with colored bars
ax = df.plot(kind='bar', x='Run', y='Response Time', color=[color_map.get(region, 'gray') for region in df['Region']], legend=False)

# Add legend
legend_labels = [plt.Rectangle((0, 0), 1, 1, color=color_map.get(region, 'gray')) for region in df['Region'].unique()]
ax.legend(legend_labels, df['Region'].unique())

plt.title('Load Balancing results')
plt.xlabel('Runs')
plt.ylabel('Response Time')
plt.xticks(df['Run'], rotation=0)

average = df['Response Time'].mean()
plt.axhline(y=average, color='r', linestyle='--', label=f'Average: {average:.2f}')

plt.show()

# %% [markdown]
# <a id='sdk'></a>
# ### 🧪 Test the API using the Azure OpenAI Python SDK
#
# Repeat the same test using the Python SDK to ensure compatibility.

# %%
import time
from openai import AzureOpenAI

runs = 9
sleep_time_ms = 0

for i in range(runs):
    print("▶️ Run: ", i+1)

    if len(openai_resources) > 0:
        messages=[
            {"role": "system", "content": "You are a sarcastic unhelpful assistant."},
            {"role": "user", "content": "Can you tell me the time, please?"}
        ]
    elif len(mock_webapps) > 0:
        messages=[
                {
                    "role": "system", 
                    "content": {
                        "simulation": {
                            "default": {"response_status_code": 200, "wait_time_ms": 0},
                            "openaimock1.azurewebsites.net": {"response_status_code": 429}
                        }
                    }
                }
            ]
    client = AzureOpenAI(
        azure_endpoint=apim_resource_gateway_url,
        api_key=apim_subscription_key,
        api_version=openai_api_version
    )
    start_time = time.time()
    response = client.chat.completions.create(model=openai_model_name, messages=messages)
    response_time = time.time() - start_time
    print(f"⌚ {response_time:.2f} seconds")
    print("💬 ", response.choices[0].message.content)
    time.sleep(sleep_time_ms/1000)

# %% [markdown]
# <a id='clean'></a>
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.
# Use the [clean-up-resources notebook](clean-up-resources.ipynb) for that.
