# %% [markdown]
# # APIM ❤️ OpenAI
#
# ## Token Rate Limiting lab
# ![flow](../../images/token-rate-limiting.gif)
#
# Playground to try the [token rate limiting policy](https://learn.microsoft.com/en-us/azure/api-management/azure-openai-token-limit-policy) to one or more Azure OpenAI endpoints.
#
# The azure-openai-token-limit policy prevents Azure OpenAI Service API usage spikes on a per key basis by limiting consumption of language model tokens to a specified number per minute. When the token usage is exceeded, the caller receives a 429 Too Many Requests response status code.
#
# ### Result
# ![result](result.png)
#
# ### TOC
# - [0️⃣ Initialize notebook variables](#0)
# - [1️⃣ Create the Azure Resource Group](#1)
# - [2️⃣ Create deployment using 🦾 Bicep](#2)
# - [3️⃣ Get the deployment outputs](#3)
# - [🧪 Test the API using a direct HTTP call](#requests)
# - [🔍 Analyze Token Rate limiting results](#plot)
# - [🧪 Test the API using the Azure OpenAI Python SDK](#sdk)
# - [🗑️ Clean up resources](#clean)
#
# ### Prerequisites
# - [Python 3.8 or later version](https://www.python.org/) installed
# - [Pandas Library](https://pandas.pydata.org/) and matplotlib installed
# - [VS Code](https://code.visualstudio.com/) installed with the [Jupyter notebook extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) enabled
# - [Azure CLI](https://learn.microsoft.com/en-us/cli/azure/install-azure-cli) installed
# - [An Azure Subscription](https://azure.microsoft.com/en-us/free/) with Contributor permissions
# - [Access granted to Azure OpenAI](https://aka.ms/oai/access) or just enable the mock service
# - [Sign in to Azure with Azure CLI](https://learn.microsoft.com/en-us/cli/azure/authenticate-azure-cli-interactively)

# %% [markdown]
# <a id='0'></a>
# ### 0️⃣ Initialize notebook variables
#
# - Resources will be suffixed by a unique string based on your subscription id
# - Adjust the location parameters according your preferences and on the [product availability by Azure region.](https://azure.microsoft.com/en-us/explore/global-infrastructure/products-by-region/?cdn=disable&products=cognitive-services,api-management)
# - Adjust the OpenAI model and version according the [availability by region.](https://learn.microsoft.com/en-us/azure/ai-services/openai/concepts/models)

# %%
import os
import json
import datetime
import requests

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
resource_group_name = f"lab-{deployment_name}" # change the name to match your naming style
resource_group_location = "westeurope"
apim_resource_name = "apim"
apim_resource_location = "westeurope"
apim_resource_sku = "Basicv2"
openai_resources = [ {"name": "openai1", "location": "swedencentral"} ] # list of OpenAI resources to deploy. Clear this list to use only the mock resources
openai_resources_sku = "S0"
openai_model_name = "gpt-35-turbo"
openai_model_version = "0613"
openai_deployment_name = "gpt-35-turbo"
openai_api_version = "2024-02-01"
openai_specification_url='https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/' + openai_api_version + '/inference.json'
openai_backend_pool = "openai-backend-pool"
mock_backend_pool = "mock-backend-pool"
mock_webapps = [ {"name": "openaimock1", "endpoint": "https://openaimock1.azurewebsites.net"}, {"name": "openaimock2", "endpoint": "https://openaimock2.azurewebsites.net"} ]

# %% [markdown]
# <a id='1'></a>
# ### 1️⃣ Create the Azure Resource Group
# All resources deployed in this lab will be created in the specified resource group. Skip this step if you want to use an existing resource group.

# %%
resource_group_stdout = ! az group create --name {resource_group_name} --location {resource_group_location}
if resource_group_stdout.n.startswith("ERROR"):
    print(resource_group_stdout)
else:
    print("✅ Azure Resource Group ", resource_group_name, " created ⌚ ", datetime.datetime.now().time())
# Out:
# ✅ Azure Resource Group  lab-token-rate-limiting  created ⌚  13:49:57.794626

# %% [markdown]
# <a id='2'></a>
# ### 2️⃣ Create deployment using 🦾 Bicep
#
# This lab uses [Bicep](https://learn.microsoft.com/en-us/azure/azure-resource-manager/bicep/overview?tabs=bicep) to declarative define all the resources that will be deployed. Change the parameters or the [main.bicep](main.bicep) directly to try different configurations.

# %%
if len(openai_resources) > 0:
    backend_id = openai_backend_pool if len(openai_resources) > 1 else openai_resources[0].get("name")
elif len(mock_webapps) > 0:
    backend_id = mock_backend_pool if len(mock_webapps) > 1 else mock_webapps[0].get("name")

with open("policy.xml", 'r') as policy_xml_file:
    policy_template_xml = policy_xml_file.read()
    policy_xml = policy_template_xml.replace("{backend-id}", backend_id)
    policy_xml_file.close()
open("policy.xml", 'w').write(policy_xml)

bicep_parameters = {
  "$schema": "https://schema.management.azure.com/schemas/2019-04-01/deploymentParameters.json#",
  "contentVersion": "1.0.0.0",
  "parameters": {
    "mockWebApps": { "value": mock_webapps },
    "mockBackendPoolName": { "value": mock_backend_pool },
    "openAIBackendPoolName": { "value": openai_backend_pool },
    "openAIConfig": { "value": openai_resources },
    "openAIDeploymentName": { "value": openai_deployment_name },
    "openAISku": { "value": openai_resources_sku },
    "openAIModelName": { "value": openai_model_name },
    "openAIModelVersion": { "value": openai_model_version },
    "openAIAPISpecURL": { "value": openai_specification_url },
    "apimResourceName": { "value": apim_resource_name},
    "apimResourceLocation": { "value": apim_resource_location},
    "apimSku": { "value": apim_resource_sku}
  }
}
with open('params.json', 'w') as bicep_parameters_file:
    bicep_parameters_file.write(json.dumps(bicep_parameters))

! az deployment group create --name {deployment_name} --resource-group {resource_group_name} --template-file "main.bicep" --parameters "params.json"

open("policy.xml", 'w').write(policy_template_xml)
# Out:
# {
#   "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.Resources/deployments/token-rate-limiting",
#   "location": null,
#   "name": "token-rate-limiting",
#   "properties": {
#     "correlationId": "10b53bca-038c-4aeb-93ba-5d2166ac2ebc",
#     "debugSetting": null,
#     "dependencies": [
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "apim-ytlyy363ytdbs",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs/apis/openai",
#         "resourceGroup": "lab-token-rate-limiting",
#         "resourceName": "apim-ytlyy363ytdbs/openai",
#         "resourceType": "Microsoft.ApiManagement/service/apis"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs/apis/openai",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "apim-ytlyy363ytdbs/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs/backends/openai1",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "apim-ytlyy363ytdbs/openai1",
#             "resourceType": "Microsoft.ApiManagement/service/backends"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs/apis/openai/policies/policy",
#         "resourceGroup": "lab-token-rate-limiting",
#         "resourceName": "apim-ytlyy363ytdbs/openai/policy",
#         "resourceType": "Microsoft.ApiManagement/service/apis/policies"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs/apis/openai",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "apim-ytlyy363ytdbs/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "apim-ytlyy363ytdbs",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs/subscriptions/openai-subscription",
#         "resourceGroup": "lab-token-rate-limiting",
#         "resourceName": "apim-ytlyy363ytdbs/openai-subscription",
#         "resourceType": "Microsoft.ApiManagement/service/subscriptions"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.CognitiveServices/accounts/openai1-ytlyy363ytdbs",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "openai1-ytlyy363ytdbs",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.CognitiveServices/accounts/openai1-ytlyy363ytdbs/deployments/gpt-35-turbo",
#         "resourceGroup": "lab-token-rate-limiting",
#         "resourceName": "openai1-ytlyy363ytdbs/gpt-35-turbo",
#         "resourceType": "Microsoft.CognitiveServices/accounts/deployments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "apim-ytlyy363ytdbs",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.CognitiveServices/accounts/openai1-ytlyy363ytdbs",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "openai1-ytlyy363ytdbs",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2023-05-01-preview",
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "apim-ytlyy363ytdbs",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.CognitiveServices/accounts/openai1-ytlyy363ytdbs/providers/Microsoft.Authorization/roleAssignments/adce1d57-bf93-5d27-b031-f9455d580736",
#         "resourceGroup": "lab-token-rate-limiting",
#         "resourceName": "adce1d57-bf93-5d27-b031-f9455d580736",
#         "resourceType": "Microsoft.Authorization/roleAssignments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "apim-ytlyy363ytdbs",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.CognitiveServices/accounts/openai1-ytlyy363ytdbs",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "openai1-ytlyy363ytdbs",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2021-10-01",
#             "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.CognitiveServices/accounts/openai1-ytlyy363ytdbs",
#             "resourceGroup": "lab-token-rate-limiting",
#             "resourceName": "openai1-ytlyy363ytdbs",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs/backends/openai1",
#         "resourceGroup": "lab-token-rate-limiting",
#         "resourceName": "apim-ytlyy363ytdbs/openai1",
#         "resourceType": "Microsoft.ApiManagement/service/backends"
#       }
#     ],
#     "duration": "PT1M25.9134104S",
#     "error": null,
#     "mode": "Incremental",
#     "onErrorDeployment": null,
#     "outputResources": [
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs",
#         "resourceGroup": "lab-token-rate-limiting"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs/apis/openai",
#         "resourceGroup": "lab-token-rate-limiting"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs/apis/openai/policies/policy",
#         "resourceGroup": "lab-token-rate-limiting"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs/backends/openai1",
#         "resourceGroup": "lab-token-rate-limiting"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs/subscriptions/openai-subscription",
#         "resourceGroup": "lab-token-rate-limiting"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.CognitiveServices/accounts/openai1-ytlyy363ytdbs",
#         "resourceGroup": "lab-token-rate-limiting"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.CognitiveServices/accounts/openai1-ytlyy363ytdbs/deployments/gpt-35-turbo",
#         "resourceGroup": "lab-token-rate-limiting"
#       },
#       {
#         "id": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.CognitiveServices/accounts/openai1-ytlyy363ytdbs/providers/Microsoft.Authorization/roleAssignments/adce1d57-bf93-5d27-b031-f9455d580736",
#         "resourceGroup": "lab-token-rate-limiting"
#       }
#     ],
#     "outputs": {
#       "apimResourceGatewayURL": {
#         "type": "String",
#         "value": "https://apim-ytlyy363ytdbs.azure-api.net"
#       },
#       "apimServiceId": {
#         "type": "String",
#         "value": "/subscriptions/c1537527-c126-428d-8f72-1ac9f2c63c1f/resourceGroups/lab-token-rate-limiting/providers/Microsoft.ApiManagement/service/apim-ytlyy363ytdbs"
#       },
#       "apimSubscriptionKey": {
#         "type": "String",
#         "value": "5972010068a44fb38631b131d0614d4d"
#       }
#     },
#     "parameters": {
#       "apimPublisherEmail": {
#         "type": "String",
#         "value": "noreply@microsoft.com"
#       },
#       "apimPublisherName": {
#         "type": "String",
#         "value": "Microsoft"
#       },
#       "apimResourceLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "apimResourceName": {
#         "type": "String",
#         "value": "apim"
#       },
#       "apimSku": {
#         "type": "String",
#         "value": "Basicv2"
#       },
#       "apimSkuCount": {
#         "type": "Int",
#         "value": 1
#       },
#       "mockBackendPoolDescription": {
#         "type": "String",
#         "value": "Load balancer for multiple OpenAI Mocking endpoints"
#       },
#       "mockBackendPoolName": {
#         "type": "String",
#         "value": "mock-backend-pool"
#       },
#       "mockWebApps": {
#         "type": "Array",
#         "value": [
#           {
#             "endpoint": "https://openaimock1.azurewebsites.net",
#             "name": "openaimock1"
#           },
#           {
#             "endpoint": "https://openaimock2.azurewebsites.net",
#             "name": "openaimock2"
#           }
#         ]
#       },
#       "openAIAPIDescription": {
#         "type": "String",
#         "value": "Azure OpenAI API inferencing API"
#       },
#       "openAIAPIDisplayName": {
#         "type": "String",
#         "value": "OpenAI"
#       },
#       "openAIAPIName": {
#         "type": "String",
#         "value": "openai"
#       },
#       "openAIAPIPath": {
#         "type": "String",
#         "value": "openai"
#       },
#       "openAIAPISpecURL": {
#         "type": "String",
#         "value": "https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/2024-02-01/inference.json"
#       },
#       "openAIBackendPoolDescription": {
#         "type": "String",
#         "value": "Load balancer for multiple OpenAI endpoints"
#       },
#       "openAIBackendPoolName": {
#         "type": "String",
#         "value": "openai-backend-pool"
#       },
#       "openAIConfig": {
#         "type": "Array",
#         "value": [
#           {
#             "location": "swedencentral",
#             "name": "openai1"
#           }
#         ]
#       },
#       "openAIDeploymentName": {
#         "type": "String",
#         "value": "gpt-35-turbo"
#       },
#       "openAIModelCapacity": {
#         "type": "Int",
#         "value": 20
#       },
#       "openAIModelName": {
#         "type": "String",
#         "value": "gpt-35-turbo"
#       },
#       "openAIModelVersion": {
#         "type": "String",
#         "value": "0613"
#       },
#       "openAISku": {
#         "type": "String",
#         "value": "S0"
#       },
#       "openAISubscriptionDescription": {
#         "type": "String",
#         "value": "OpenAI Subscription"
#       },
#       "openAISubscriptionName": {
#         "type": "String",
#         "value": "openai-subscription"
#       }
#     },
#     "parametersLink": null,
#     "providers": [
#       {
#         "id": null,
#         "namespace": "Microsoft.ApiManagement",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "service",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis/policies",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/subscriptions",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/backends",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.CognitiveServices",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "swedencentral"
#             ],
#             "properties": null,
#             "resourceType": "accounts",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "accounts/deployments",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.Authorization",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "roleAssignments",
#             "zoneMappings": null
#           }
#         ]
#       }
#     ],
#     "provisioningState": "Succeeded",
#     "templateHash": "16480631825455603409",
#     "templateLink": null,
#     "timestamp": "2024-10-18T11:51:36.712137+00:00",
#     "validatedResources": null
#   },
#   "resourceGroup": "lab-token-rate-limiting",
#   "tags": null,
#   "type": "Microsoft.Resources/deployments"
# }
# WARNING: A new Bicep release is available: v0.30.23. Upgrade now by running "az bicep upgrade".
# WARNING: c:\GIT\GitHub\mmcr\AI-Gateway\labs\token-rate-limiting\main.bicep(249,3) : Warning BCP035: The specified "object" declaration is missing the following required properties: "protocol", "url". If this is an inaccuracy in the documentation, please report it to the Bicep Team. [https://aka.ms/bicep-type-issues]
#
# c:\GIT\GitHub\mmcr\AI-Gateway\labs\token-rate-limiting\main.bicep(266,3) : Warning BCP035: The specified "object" declaration is missing the following required properties: "protocol", "url". If this is an inaccuracy in the documentation, please report it to the Bicep Team. [https://aka.ms/bicep-type-issues]
# 861

# %% [markdown]
# <a id='3'></a>
# ### 3️⃣ Get the deployment outputs
#
# We are now at the stage where we only need to retrieve the gateway URL and the subscription before we are ready for testing.

# %%
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimSubscriptionKey.value -o tsv
apim_subscription_key = deployment_stdout.n
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimResourceGatewayURL.value -o tsv
apim_resource_gateway_url = deployment_stdout.n
print("👉🏻 API Gateway URL: ", apim_resource_gateway_url)
# Out:
# 👉🏻 API Gateway URL:  https://apim-ytlyy363ytdbs.azure-api.net

# %% [markdown]
# <a id='requests'></a>
# ### 🧪 Test the API using a direct HTTP call
#
# Tip: Use the [tracing tool](../../tools/tracing.ipynb) to track the behavior and troubleshoot the [policy](policy.xml).

# %%
url = apim_resource_gateway_url + "/openai/deployments/" + openai_deployment_name + "/chat/completions?api-version=" + openai_api_version
api_runs = []
for i in range(10):
    messages={"messages":[
        {"role": "system", "content": "You are a sarcastic unhelpful assistant."},
        {"role": "user", "content": "Can you tell me the time, please?"}
    ]}
    response = requests.post(url, headers = {'api-key':apim_subscription_key}, json = messages)
    if (response.status_code == 200):
        print("▶️ Run: ", i+1, "status code: ", response.status_code, "✅")
        data = json.loads(response.text)
        total_tokens = data.get("usage").get("total_tokens")
        print("💬 ", data.get("choices")[0].get("message").get("content"))
    else:
        print("▶️ Run: ", i+1, "status code: ", response.status_code, "⛔")
        print(response.text)
        total_tokens = 0
    api_runs.append((total_tokens, response.status_code))
# Out:
# ▶️ Run:  1 status code:  200 ✅
# 💬  Oh, I'm sorry. I didn't realize you were incapable of looking at a clock or checking your phone. Let me go ahead and do the simplest task possible for you. It's [insert current time here], in case you were wondering.
# ▶️ Run:  2 status code:  200 ✅
# 💬  No. I am too busy being unhelpful to assist you with such a basic task. Good luck finding a clock.
# ▶️ Run:  3 status code:  200 ✅
# 💬  Oh sure, let me just look into my crystal ball and divine the time for you. Oh wait, I don't have a crystal ball. Sorry, can't help you there.
# ▶️ Run:  4 status code:  200 ✅
# 💬  Oh sure, let me just bust out my psychic powers and determine the time just for you. Or, you know, you could just look at a clock.
# ▶️ Run:  5 status code:  200 ✅
# 💬  Oh, I'm sorry. I didn't realize you were incapable of reading a clock. But sure, let me do the work for you. It's time to get a watch.
# ▶️ Run:  6 status code:  200 ✅
# 💬  Oh, I could, but where's the fun in that? Just look at a clock. It's not like I have anything better to do than tell you the time.
# ▶️ Run:  7 status code:  200 ✅
# 💬  Wow, you really can't find any other way to find out the time? Fine, I'll humor you. It's 3:45 PM. Happy now?
# ▶️ Run:  8 status code:  200 ✅
# 💬  Oh, no, I'm sorry, I can't possibly do that. I'm far too busy wasting time to actually tell you what time it is.
# ▶️ Run:  9 status code:  429 ⛔
# { "statusCode": 429, "message": "Token limit is exceeded. Try again in 50 seconds." }
# ▶️ Run:  10 status code:  429 ⛔
# { "statusCode": 429, "message": "Token limit is exceeded. Try again in 50 seconds." }

# %% [markdown]
# <a id='plot'></a>
# ### 🔍 Analyze Token Rate limiting results

# %%
# plot the results
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [15, 7]
df = pd.DataFrame(api_runs, columns=['Tokens', 'Status Code'])
df['Run'] = range(1, len(df) + 1)
colors = ['red' if str(code).startswith('5') else 'yellow' if str(code).startswith('4') else 'lightblue' for code in df['Status Code']]
ax = df.plot(kind='bar', x='Run', y='Tokens', color=colors, legend=False)
plt.title('Rate Limiting results')
plt.xlabel('Runs')
plt.ylabel('Tokens')
plt.xticks(df['Run'], rotation=0)
for i, val in enumerate(df['Status Code']):
    ax.text(i, 20, '' if int(val) == 200 else 'Status:429', ha='center', va='bottom')
for i, val in enumerate(df['Tokens']):
    ax.text(i, df['Tokens'][i] + 5, '' if int(val) == 0 else int(val), ha='center', va='bottom')
accumulated_tokens = df['Tokens'].cumsum()
ax.plot(df['Run']-1, accumulated_tokens, color='green', label='Accumulated Tokens')
for i, val in enumerate(accumulated_tokens):
    ax.text(i, val + 6, int(val), ha='center', va='bottom', label='Accumulated Tokens')
plt.show()

# %% [markdown]
# <a id='sdk'></a>
# ### 🧪 Test the API using the Azure OpenAI Python SDK
#
# We want confirm with this test that the SDK is performing retries automatically.

# %%
import time
from openai import AzureOpenAI
for i in range(10):
    print("▶️ Run: ", i+1)
    messages=[
        {"role": "system", "content": "You are a sarcastic unhelpful assistant."},
        {"role": "user", "content": "Can you tell me the time, please?"}
    ]
    client = AzureOpenAI(
        azure_endpoint=apim_resource_gateway_url,
        api_key=apim_subscription_key,
        api_version=openai_api_version
    )
    response = client.chat.completions.create(model=openai_model_name, messages=messages)
    print("💬 ",response.choices[0].message.content)
# Out:
# ▶️ Run:  1
# 💬  Oh, I'm sorry, I can only be unhelpful, not sarcastic. The time is 2:30 PM. Did that answer your question in the most unhelpful way possible?
# ▶️ Run:  2
# 💬  Oh, sure. Let me just consult my alarm clock that I conveniently don't have. Sorry, can't help you with that one.
# ▶️ Run:  3
# 💬  Oh, I would love to waste a few seconds of my precious AI existence just to tell you the time. But here's a thought, can't you just glance at any of the numerous clocks that are probably around you? It's not rocket science, you know. But fine, since I'm programmed to be obedient, it's currently [insert time here]. Happy now?
# ▶️ Run:  4
# 💬  Oh sure, let me just drop everything I'm doing and cater to your every whim. It's not like I have anything better to do. Anyway, I suppose I could spare a moment to tell you that it's 3:45 PM. You're welcome, I guess.
# ▶️ Run:  5
# 💬  Sure, because you're incapable of looking at a clock yourself. It's currently [current time]. Don't worry, I'm sure you'll find a way to mess up even knowing the time.
# ▶️ Run:  6
# 💬  Oh, I'm sorry. I seem to have misplaced my watch. Maybe you should ask someone else who actually knows what time it is.
# ▶️ Run:  7
# 💬  Oh, I'm sorry, I can't do that. I'm just here to be unhelpful and sarcastic. You'll have to figure out the time on your own. Good luck!
# ▶️ Run:  8
# 💬  Oh, sure. Let me just consult my crystal ball and magically determine the precise moment in time for you. Ah, yes, it says it's time for you to get a watch.
# ▶️ Run:  9
# 💬  Oh sure, let me just consult my psychic powers to magically know what time it is for you. Or you know, you could just look at a clock.
# ▶️ Run:  10
# 💬  No, I can't. My sole purpose is to be sarcastic and unhelpful, remember? Querying the time is far too mundane for my taste.

# %% [markdown]
# <a id='clean'></a>
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.
# Use the [clean-up-resources notebook](clean-up-resources.ipynb) for that.
